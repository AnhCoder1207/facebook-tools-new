# %%
import time
import os
import pyautogui


def click_to(btn, region=None):
    while True:
        ret = pyautogui.locateOnScreen(f"btn/{btn}", confidence=.8, region=region)
        if ret:
            pyautogui.click(ret)
            break

def click_many(btn, region=None):
    results = pyautogui.locateAllOnScreen(f"btn/{btn}", confidence=.8, region=region)
    for ret in results:
        pyautogui.click(ret)

def check_exist(btn, region=None):
    return pyautogui.locateOnScreen(f"btn/{btn}", confidence=.8, region=region)

def waiting_for(btn, region=None):
    while True:
        ret = pyautogui.locateCenterOnScreen(f"btn/{btn}", confidence=.8, region=region)
        if ret:
            x, y = ret
            return x, y

# %%
os.listdir("btn")
# Out:
# ['all_schedule.png',
#  'auto_schedule.png',
#  'before_start_1.png',
#  'before_start_2.png',
#  'before_start_3.png',
#  'close_step.png',
#  'create_new.png',
#  'done.png',
#  'finish.png',
#  'next.png',
#  'open.PNG',
#  'schedule.PNG',
#  'sort_1.png',
#  'sort_2.png',
#  'title.png',
#  'upload_done.png',
#  'upload_new_video.png']

# %%
x, y = pyautogui.locateCenterOnScreen("btn/create_new.png")
pyautogui.click(x, y)
time.sleep(1)
pyautogui.moveTo(x, y+120)

# %%
start_date = pyautogui.prompt('Nhập thời gian bắt đầu lên lịch. \nChú ý định dạng kiểu: DD-MM-YYYY HH:MM')
interval = pyautogui.prompt('Mỗi video sẽ lên lịch cách nhau bao nhiêu tiếng?')

# %%
from datetime import datetime

# %%
date_time_str = '18/9/2021 24:00'

date_time_obj = datetime.strptime(date_time_str, '%d/%m/%Y %H:%M')
date_time_obj.timestamp()

date_obj_fromtimestamp = datetime.fromtimestamp(date_time_obj.timestamp() + 3600)
print(date_obj_fromtimestamp.strftime("%d/%m/%Y"))
print(date_obj_fromtimestamp.strftime("%H"))
print(date_obj_fromtimestamp.strftime("%M"))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-132-d19e96321b5f> in <module>
#       1 date_time_str = '18/9/2021 24:00'
#       2
# ----> 3 date_time_obj = datetime.strptime(date_time_str, '%d/%m/%Y %H:%M')
#       4 date_time_obj.timestamp()
#       5
#
# ~\AppData\Local\Programs\Python\Python37\lib\_strptime.py in _strptime_datetime(cls, data_string, format)
#     575     """Return a class cls instance based on the input string and the
#     576     format string."""
# --> 577     tt, fraction, gmtoff_fraction = _strptime(data_string, format)
#     578     tzname, gmtoff = tt[-2:]
#     579     args = tt[:6] + (fraction,)
#
# ~\AppData\Local\Programs\Python\Python37\lib\_strptime.py in _strptime(data_string, format)
#     357     if not found:
#     358         raise ValueError("time data %r does not match format %r" %
# ...

# %%
x, y = waiting_for("create_new.png")
pyautogui.click(x, y)
time.sleep(1)
pyautogui.click(x, y+120)
time.sleep(5)
pyautogui.typewrite(r"C:\Users\Administrator\Downloads\drive-download-20210611T070947Z-001\2.1M Views -Smart welding.mkv", interval=5)
click_to("open.PNG")
click_to("upload_done.png")
click_many("close_step.png")
title = waiting_for("title.png")
title_x, title_y = title
pyautogui.click(title_x + 50, title_y)
pyautogui.typewrite("Demo title", interval=3)
click_to("next.png")
click_to("schedule.PNG")
schedule_x, schedule_y = waiting_for("auto_schedule.png")
pyautogui.click(schedule_x + 30, schedule_y)
time.sleep(1)
pyautogui.click(schedule_x + 120, schedule_y)
pyautogui.typewrite("12", interval=1)
pyautogui.click(schedule_x + 130, schedule_y)
pyautogui.typewrite("30", interval=1)
click_to("finish.png")
waiting_for("done.png")
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-82-b28646f9449b> in <module>
#       1 click_to("create_new.png")
# ----> 2 click_to("upload_new_video.png")
#       3 pyautogui.typewrite(r"C:\Users\Administrator\Downloads\drive-download-20210611T070947Z-001\2.1M Views -Smart welding.mkv", interval=5)
#       4 click_to("open.PNG")
#       5 click_to("upload_done.png")
#
# <ipython-input-63-e9f5361c5bfb> in click_to(btn)
#       6 def click_to(btn):
#       7     while True:
# ----> 8         ret = pyautogui.locateOnScreen(f"btn/{btn}")
#       9         if ret:
#      10             pyautogui.click(ret)
#
# e:\projects\thinh\get facebook links\venv\lib\site-packages\pyautogui\__init__.py in wrapper(*args, **kwargs)
#     173     def wrapper(*args, **kwargs):
#     174         try:
# --> 175             return wrappedFunction(*args, **kwargs)
# ...

# %%
check_exist("like.PNG", region=(1050, 200, 80, 800))
# Out:
# Box(left=1082, top=448, width=32, height=28)

# %%
time.sleep(3)
pyautogui.position()
# Out:
# Point(x=1635, y=655)

# %%
pyautogui.screenshot(region=(900, 200, 80, 800))
# Out:
# <PIL.Image.Image image mode=RGB size=80x800 at 0x1BDA6BA0D48>
